# %%
import sys
import os

# 1. Define the absolute path to the folder containing cus_stats.py
# Based on your description and username 'leonhu' from the snippet:
custom_lib_path = "/your/document/path"

# 2. Check if the path exists (good practice to debug path issues)
if os.path.exists(custom_lib_path):
    # 3. Add the path to sys.path if it's not already there
    if custom_lib_path not in sys.path:
        sys.path.append(custom_lib_path)
        print(f"Successfully added '{custom_lib_path}' to system path.")
else:
    print(f"Error: The path '{custom_lib_path}' was not found. Please verify the folder structure.")

# %load_ext autoreload
# %autoreload 2

import cus_stats
